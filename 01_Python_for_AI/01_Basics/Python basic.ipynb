# %%
#python basics

# %%
name= "Anjanaa"
age=25
height=5.1
is_learning=True
print(name)
print(type(age))
# Out:
# Anjanaa
# <class 'int'>

# %%
Name="Anjanaa Reddy"
age=24
fav_number=1
print(Name)
print(age)
print(fav_number)
print(type(Name))
print(type(age))
print(type(fav_number))
print(Name,",",age,",",fav_number)
# Out:
# Anjanaa Reddy
# 24
# 1
# <class 'str'>
# <class 'int'>
# <class 'int'>
# Anjanaa Reddy , 24 , 1

# %%
#Practice Excercises
city="Hyderabad"
pincode=500090
temperature_today= 31.5
print(city, type(city))
print(pincode, type(pincode))
print(temperature_today, type(temperature_today))
# Out:
# Hyderabad <class 'str'>
# 500090 <class 'int'>
# 31.5 <class 'float'>

# %%
name=input()
print("Hello,", name)
# Out:
# Anjanaa
# Hello, Anjanaa

# %%
num= int(input())
print(type(num))
# Out:
# 3
# <class 'int'>

# %%
x=5
y="5"
print(x+y)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-12-05d2dc7f30cd> in <module>
#       1 x=5
#       2 y="5"
# ----> 3 print(x+y)
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
num=input()
print(num+1)
# Out:
# 3
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-13-c6b4452547dd> in <module>
#       1 num=input()
# ----> 2 print(num+1)
#
# TypeError: can only concatenate str (not "int") to str
